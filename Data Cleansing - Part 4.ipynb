# %%
# Importing the required packages
import numpy as np
import pandas as pd 
import matplotlib.pyplot as plt
import seaborn as sns
pd.options.display.float_format = '{:,.2f}'.format

# %%
# Loading the data
filePath = 'data/bigmart.csv'
data = pd.read_csv(filePath)
data.head()
# Out:
#   Item_Identifier  Item_Weight Item_Fat_Content  ...  Outlet_Location_Type        Outlet_Type  Item_Outlet_Sales
# 0           FDA15         9.30          Low Fat  ...                Tier 1  Supermarket Type1           3,735.14
# 1           DRC01         5.92          Regular  ...                Tier 3  Supermarket Type2             443.42
# 2           FDN15        17.50          Low Fat  ...                Tier 1  Supermarket Type1           2,097.27
# 3           FDX07        19.20          Regular  ...                Tier 3      Grocery Store             732.38
# 4           NCD19         8.93          Low Fat  ...                Tier 3  Supermarket Type1             994.71
#
# [5 rows x 12 columns]

# %% [markdown]
# From the data above, it is clear that only the numerical values have the potential of having outliers. We will plot a box plot for the numerical values to check for outliers.

# %%
# Check for univariate outliers
plt.rcParams['figure.figsize']=(16,4)

plt.subplot(1,4,1) 
sns.boxplot(data['Item_Weight'])

plt.subplot(1,4,2) 
sns.boxplot(data['Item_Visibility'])

plt.subplot(1,4,3) 
sns.boxplot(data['Item_MRP'])

plt.subplot(1,4,4) 
sns.boxplot(data['Item_Outlet_Sales'])

plt.suptitle('Univariate outliers')
plt.show()
# Out:
# C:\Anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# C:\Anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# C:\Anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# ...

# %% [markdown]
# The box plot above shows that we have outliers on both the item visibility and item outlet sales

# %%
# Working with bivariate outlies

plt.subplot(1,3,1)
sns.scatterplot(x=data['Item_Weight'], y=data['Item_Outlet_Sales'])

plt.subplot(1,3,2)
sns.scatterplot(x=data['Item_Visibility'], y=data['Item_Outlet_Sales'])

plt.subplot(1,3,3)
sns.scatterplot( y=['Item_Outlet_Sales'],x=data['Item_MRP'])

plt.suptitle('Working with bivariate outliers')
plt.show()
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# ~\AppData\Local\Temp/ipykernel_21324/818119273.py in <module>
#       8
#       9 plt.subplot(1,3,3)
# ---> 10 sns.scatterplot( y=['Item_Outlet_Sales'],x=data['Item_MRP'])
#      11
#      12 plt.suptitle('Working with bivariate outliers')
#
# C:\Anaconda3\lib\site-packages\seaborn\_decorators.py in inner_f(*args, **kwargs)
#      44             )
#      45         kwargs.update({k: arg for k, arg in zip(sig.parameters, args)})
# ---> 46         return f(**kwargs)
#      47     return inner_f
#      48
#
# C:\Anaconda3\lib\site-packages\seaborn\relational.py in scatterplot(x, y, hue, style, size, data, palette, hue_order, hue_norm, sizes, size_order, size_norm, markers, style_order, x_bins, y_bins, units, estimator, ci, n_boot, alpha, x_jitter, y_jitter, legend, ax, **kwargs)
#     806
# ...
